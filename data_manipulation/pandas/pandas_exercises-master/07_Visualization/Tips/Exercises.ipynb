# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# inline graph printing for the notebook
# %matplotlib inline

# set seaborn style to white
sns.set_style("white")

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips.drop(columns=['Unnamed: 0'], inplace=True)
tips.head()
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
sns.displot(data=tips, x=tips.total_bill, kde=True)

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
fig = plt.gcf()
fig.set_size_inches(12, 6)

sns.jointplot(data=tips, x=tips.total_bill, y=tips.tip)
# take out the right and upper borders
sns.despine()

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
fig = plt.gcf()
fig.set_size_inches(12, 6)

sns.pairplot(tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
# get current figure and change its size
fig = plt.gcf()
fig.set_size_inches(12, 6)

sns.stripplot(data=tips, x=tips.day, y=tips.total_bill)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
# get current figure and change its size
fig = plt.gcf()
fig.set_size_inches(12, 6)

# plot the scatterplot
sns.stripplot(data=tips, x=tips.tip, y=tips.day, hue='sex', jitter=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
# get current figure and change its size
fig = plt.gcf()
fig.set_size_inches(12, 6)


# plot the boxplot
sns.boxplot(data=tips, y=tips.total_bill, x=tips.day, hue=tips.time)
# take out the right and upper borders
sns.despine()

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
# create a FacetGrid and map it to histplot
g = sns.FacetGrid(data=tips, col='time')
g.map(sns.histplot, 'tip')

# change FacetGrid size
g.fig.set_figwidth(12)
g.fig.set_figheight(6)

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
# create a FacetGrid and map it to a scatterplot
g = sns.FacetGrid(data=tips, col='sex')
g.map(sns.scatterplot, x=tips.total_bill, y=tips.tip, hue=tips.smoker, alpha=.7)

# add axis names, legend 
g.add_legend(title='Smoker')
g.set_axis_labels(x_var='Total Bill', y_var='Tip')

# change FacetGrid size
g.fig.set_figwidth(12)
g.fig.set_figheight(6)

g.axes_dict
# Out:
# {'Female': <AxesSubplot:title={'center':'sex = Female'}, xlabel='Total Bill', ylabel='Tip'>,
#  'Male': <AxesSubplot:title={'center':'sex = Male'}, xlabel='Total Bill'>}

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %% [markdown]
# #### Create a boxplot for the total_bill grouped by day of the week

# %%
fig = plt.gcf()
fig.set_size_inches(12, 6)
sns.boxplot(data=tips, x=tips.day, y=tips.total_bill, orient='v')
# take out the right and upper borders
sns.despine()
